# %% [markdown]
# Write a program for hidden Markov model that calculates most probable path based upon the given observation. The program should take as input a sequence of probable observations. The graph size should be parameterized, and the weights of the graphs should be generated using a random number generator.

# %%
import random
import numpy as np

# %%
graph_size=4

# %%
#generating random numbers whose sum is 1.
x=np.random.dirichlet(np.ones(graph_size))

# %%
x
# Out:
# array([0.12099903, 0.10231903, 0.05827532, 0.71840662])

# %%
sum(x)
# Out:
# 0.9999999999999999

# %%
#transition_probabilities
transition_probabilities=[]
for i in range(graph_size):
    transition_probabilities.append(np.random.dirichlet(np.ones(graph_size)))

# %%
transition_probabilities
# Out:
# [array([0.04805768, 0.11146709, 0.11747627, 0.72299897]),
#  array([0.1266807 , 0.58392683, 0.26439735, 0.02499512]),
#  array([0.26604173, 0.65620153, 0.06314786, 0.01460888]),
#  array([0.37414908, 0.51908903, 0.03866065, 0.06810125])]

# %%
#Initial Probabilities
initial_probabilities=np.random.dirichlet(np.ones(graph_size))

# %%
initial_probabilities
# Out:
# array([0.42918834, 0.10699867, 0.28235414, 0.18145886])

# %%
#User Input
max_observation=3

# %%
#Emission Probabilities
emission_probabilities=[]
for i in range(graph_size):
    emission_probabilities.append(np.random.dirichlet(np.ones(max_observation)))

# %%
emission_probabilities
# Out:
# [array([0.51081086, 0.02603277, 0.46315637]),
#  array([0.1150615 , 0.20183773, 0.68310076]),
#  array([0.38264588, 0.27249543, 0.3448587 ]),
#  array([0.58831904, 0.22849965, 0.18318131])]

# %%
#User Input
output_sequence='ABCA'

# %%
output_seq_int=[]
for i in output_sequence:
    output_seq_int.append(ord(i)-65)

# %%
output_seq_int
# Out:
# [0, 1, 2, 0]

# %%
sequence_list=[]
for i in range(graph_size):
    sequence_list.append(i)

# %%
sequence_list
# Out:
# [0, 1, 2, 3]

# %%
def possible_path(past_sequence):
    seq_list=[]
    for i in range(len(past_sequence)):
        for j in range(graph_size):
            seq_list.append(str(past_sequence[i]) + str(j))
    return seq_list

# %%
possible_path(sequence_list)
# Out:
# ['00',
#  '01',
#  '02',
#  '03',
#  '10',
#  '11',
#  '12',
#  '13',
#  '20',
#  '21',
#  '22',
#  '23',
#  '30',
#  '31',
#  '32',
#  '33']

# %%
for i in range(len(output_seq_int)-1):
    new_chain=possible_path(sequence_list)
    sequence_list=new_chain

# %%
sequence_list
# Out:
# ['0000',
#  '0001',
#  '0002',
#  '0003',
#  '0010',
#  '0011',
#  '0012',
#  '0013',
#  '0020',
#  '0021',
#  '0022',
#  '0023',
#  '0030',
#  '0031',
#  '0032',
#  '0033',
#  '0100',
#  '0101',
#  '0102',
#  '0103',
#  '0110',
#  '0111',
#  '0112',
#  '0113',
#  '0120',
#  '0121',
#  '0122',
#  '0123',
#  '0130',
#  '0131',
#  '0132',
#  '0133',
#  '0200',
#  '0201',
#  '0202',
#  '0203',
#  '0210',
#  '0211',
#  '0212',
#  '0213',
#  '0220',
#  '0221',
#  '0222',
#  '0223',
#  '0230',
#  '0231',
#  '0232',
#  '0233',
#  '0300',
#  '0301',
#  '0302',
#  '0303',
#  '0310',
#  '0311',
#  '0312',
#  '0313',
#  '0320',
#  '0321',
#  '0322',
#  '0323',
#  '0330',
#  '0331',
#  '0332',
#  '0333',
#  '1000',
#  '1001',
#  '1002',
#  '1003',
#  '1010',
#  '1011',
#  '1012',
#  '1013',
#  '1020',
#  '1021',
#  '1022',
#  '1023',
#  '1030',
#  '1031',
#  '1032',
#  '1033',
#  '1100',
#  '1101',
#  '1102',
#  '1103',
#  '1110',
#  '1111',
#  '1112',
#  '1113',
#  '1120',
#  '1121',
#  '1122',
#  '1123',
#  '1130',
#  '1131',
#  '1132',
#  '1133',
#  '1200',
#  '1201',
#  '1202',
#  '1203',
#  '1210',
#  '1211',
#  '1212',
#  '1213',
#  '1220',
#  '1221',
#  '1222',
#  '1223',
#  '1230',
#  '1231',
#  '1232',
#  '1233',
#  '1300',
#  '1301',
#  '1302',
#  '1303',
#  '1310',
#  '1311',
#  '1312',
#  '1313',
#  '1320',
#  '1321',
#  '1322',
#  '1323',
#  '1330',
#  '1331',
#  '1332',
#  '1333',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '2030',
#  '2031',
#  '2032',
#  '2033',
#  '2100',
#  '2101',
#  '2102',
#  '2103',
#  '2110',
#  '2111',
#  '2112',
#  '2113',
#  '2120',
#  '2121',
#  '2122',
#  '2123',
#  '2130',
#  '2131',
#  '2132',
#  '2133',
#  '2200',
#  '2201',
#  '2202',
#  '2203',
#  '2210',
#  '2211',
#  '2212',
#  '2213',
#  '2220',
#  '2221',
#  '2222',
#  '2223',
#  '2230',
#  '2231',
#  '2232',
#  '2233',
#  '2300',
#  '2301',
#  '2302',
#  '2303',
#  '2310',
#  '2311',
#  '2312',
#  '2313',
#  '2320',
#  '2321',
#  '2322',
#  '2323',
#  '2330',
#  '2331',
#  '2332',
#  '2333',
#  '3000',
#  '3001',
#  '3002',
#  '3003',
#  '3010',
#  '3011',
#  '3012',
#  '3013',
#  '3020',
#  '3021',
#  '3022',
#  '3023',
#  '3030',
#  '3031',
#  '3032',
#  '3033',
#  '3100',
#  '3101',
#  '3102',
#  '3103',
#  '3110',
#  '3111',
#  '3112',
#  '3113',
#  '3120',
#  '3121',
#  '3122',
#  '3123',
#  '3130',
#  '3131',
#  '3132',
#  '3133',
#  '3200',
#  '3201',
#  '3202',
#  '3203',
#  '3210',
#  '3211',
#  '3212',
#  '3213',
#  '3220',
#  '3221',
#  '3222',
#  '3223',
#  '3230',
#  '3231',
#  '3232',
#  '3233',
#  '3300',
#  '3301',
#  '3302',
#  '3303',
#  '3310',
#  '3311',
#  '3312',
#  '3313',
#  '3320',
#  '3321',
#  '3322',
#  '3323',
#  '3330',
#  '3331',
#  '3332',
#  '3333']

# %%
prob_seq=[]
for i in range(len(sequence_list)):
    initial_state=int(sequence_list[i][0])
    first_obs=output_seq_int[0]
    i_prob= initial_probabilities[initial_state] * emission_probabilities[initial_state][first_obs]
     
    for j in range(1, len(output_seq_int)):
        next_state=int(sequence_list[i][j])
        prob = i_prob * transition_probabilities[initial_state][next_state] * emission_probabilities[next_state][output_seq_int[j]]
        initial_state=next_state
        i_prob = prob
       
    prob_seq.append(prob)

# %%
len(prob_seq)
# Out:
# 256

# %%
prob_seq
# Out:
# [1.4986649727690886e-07,
#  7.829938524778505e-08,
#  2.744282563341249e-07,
#  2.5967625173592937e-06,
#  1.3514289886689966e-06,
#  1.4031727153685046e-06,
#  2.1128894593887196e-06,
#  3.0710775702407545e-07,
#  1.5100538563842843e-06,
#  8.389765823179184e-07,
#  2.6849626542080396e-07,
#  9.550195577300513e-08,
#  6.942483561085082e-06,
#  2.1696114345524977e-06,
#  5.373734723508159e-07,
#  1.4553854450194008e-06,
#  7.104246982529047e-06,
#  3.711691281825692e-06,
#  1.3008952283578901e-05,
#  0.00012309650664756502,
#  0.000127312436714256,
#  0.00013218699541177139,
#  0.0001990464225927079,
#  2.8931329140047833e-05,
#  6.111744749985568e-05,
#  3.39564757949764e-05,
#  1.0867033871927857e-05,
#  3.865316288828311e-06,
#  4.31616693550725e-06,
#  1.3488552121613272e-06,
#  3.3408701554300833e-07,
#  9.048183522424418e-07,
#  2.12284214615475e-05,
#  1.1091020210800379e-05,
#  3.8872455100183385e-05,
#  0.0003678285017377645,
#  0.00020356822116011794,
#  0.00021136247338404598,
#  0.0003182684050453449,
#  4.626020332998572e-05,
#  2.0769551792307878e-05,
#  1.1539434507792174e-05,
#  3.6929458291317318e-06,
#  1.313551042108891e-06,
#  3.589385932947855e-06,
#  1.1217272168705553e-06,
#  2.7783152317524425e-07,
#  7.524598362251232e-07,
#  0.00015407297568721123,
#  8.049710574949392e-05,
#  0.00028213095544581145,
#  0.00266964889066107,
#  0.0008310524794688274,
#  0.0008628719481431934,
#  0.0012993076504877468,
#  0.0001888539206120873,
#  6.562229946779165e-05,
#  3.6459343684044085e-05,
#  1.1668022475447275e-05,
#  4.15022147388965e-06,
#  8.63519728072883e-05,
#  2.6986052750491057e-05,
#  6.683956694100275e-06,
#  1.8102369745157296e-05,
#  2.2184651196618136e-08,
#  1.159061286007236e-08,
#  4.062345658229189e-08,
#  3.843972584588067e-07,
#  2.0005125411868487e-07,
#  2.0771084815270512e-07,
#  3.127698086313519e-07,
#  4.546098423029342e-08,
#  2.2353240184225663e-07,
#  1.2419321982593347e-07,
#  3.974534738707678e-08,
#  1.4137099457954785e-08,
#  1.0276918393331826e-06,
#  7.359921781602348e-08,
#  1.993310721231967e-07,
#  1.534223949787062e-06,
#  8.015720276613472e-07,
#  2.8093964362706803e-06,
#  2.6583761670766822e-05,
#  8.275433195497294e-06,
#  8.592284289545216e-06,
#  1.2938212601065005e-05,
#  1.8805647565506124e-06,
#  6.534520608466547e-07,
#  3.630539231431298e-07,
#  1.1618753677365905e-07,
#  4.1326969598410775e-08,
#  8.598734736016366e-07,
#  2.68721028170919e-07,
#  6.655733358617403e-08,
#  1.8025931599649332e-07,
#  5.681584797492057e-07,
#  2.968405914330616e-07,
#  1.0403842336484993e-06,
#  9.844579482007412e-06,
#  5.123398849260279e-06,
#  5.319564354108444e-06,
#  8.010169617204901e-06,
#  1.1642754019104683e-06,
#  5.72476116391433e-06,
#  3.1806418927252635e-06,
#  1.0178954786536377e-06,
#  3.6205721085753837e-07,
#  2.6319630987717107e-05,
#  8.22520814658267e-06,
#  2.037235143650972e-06,
#  5.517507894799844e-06,
#  1.6110027919869992e-05,
#  8.416859707608771e-06,
#  2.9499901257952315e-05,
#  0.00027914121845814166,
#  0.00028870152108411156,
#  0.00029975537055009144,
#  0.0004513699246668407,
#  6.560646347900438e-05,
#  0.00013859368741475734,
#  7.700179547005534e-05,
#  2.4642755173555073e-05,
#  8.765229233342994e-06,
#  9.787605922040762e-06,
#  3.0587471383273093e-06,
#  7.575962887129114e-07,
#  2.0518218120630916e-06,
#  3.4018858085284242e-06,
#  1.7773523257754884e-06,
#  6.229368188657221e-06,
#  5.894505921227156e-05,
#  3.262210729546625e-05,
#  3.387114769522939e-05,
#  5.100298071563762e-05,
#  7.413265724584205e-06,
#  3.328351268120981e-06,
#  1.8492113773795274e-06,
#  5.918000088015805e-07,
#  2.104984893493919e-07,
#  5.75204382895116e-07,
#  1.7975843879980383e-07,
#  4.4522910832711545e-08,
#  1.2058279712312002e-07,
#  7.066866656846006e-06,
#  3.692161523176991e-06,
#  1.2940503245369616e-05,
#  0.00012244881132950436,
#  3.811789206414955e-05,
#  3.957735593969602e-05,
#  5.959535649429878e-05,
#  8.662164592041307e-06,
#  3.0098986404725672e-06,
#  1.672281067215388e-06,
#  5.351772990382531e-07,
#  1.9035824823620574e-07,
#  3.960706766795776e-06,
#  1.237769540905688e-06,
#  3.065731059367121e-07,
#  8.303015671071286e-07]

# %%
def max_val(prob_seq):
    maxval=prob_seq[0]
    maxid=0
    for i in range(len(prob_seq)):
        if  prob_seq[i] > maxval:
            maxval=prob_seq[i]
            maxid=i
    return maxid

# %%
max_val(prob_seq)
# Out:
# 51

# %%
#Maximum Probability
prob_seq[max_val(prob_seq)]
# Out:
# 0.00266964889066107

# %%
#Maximum probabilities Path 
sequence_list[max_val(prob_seq)]
# Out:
# '0303'
